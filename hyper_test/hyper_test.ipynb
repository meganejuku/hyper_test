# %%
import tifffile
import numpy as np
import matplotlib

img = tifffile.imread(r"2025_4_10/battery/session_000_003_cube.tiff")
num_img = np.array(img)
m = np.max(num_img)
print(m)
if m > 255:
    num_img = num_img / m * 255
jpeg_img = num_img.astype(np.uint8)
print(jpeg_img.shape)
tifffile.imshow(jpeg_img)
# Out:
# 3083
# (275, 290, 51)
# (<Figure size 988.8x604.8 with 3 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7f238c0ef530>)
